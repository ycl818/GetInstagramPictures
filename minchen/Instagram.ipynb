# %%
import requests
headers = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.85 Safari/537.36',
    'cookie': 'mid=XwV5YAALAAE90Aw6LG7W7laZDp5m; ig_did=91D806D8-1651-43C7-BAA2-73678E1445F6; fbm_124024574287414=base_domain=.instagram.com; shbid=3317; shbts=1619426000.8690197; rur=RVA; ig_nrcb=1; csrftoken=ANFV9V6YPFUaUcdXiuQshMHpakJ5BX7c; ds_user_id=1436029325; sessionid=1436029325%3AI6G5IavOGE8yqW%3A18; fbsr_124024574287414=Rmw_BgAqOV2z_HvA9RbnGYF0TQt3hTnJHq2uCzcPjgg....; fbsr_124024574287414=Rmw_BgAqOV2z_HvA9RbnGYF0TQt3hTnJHq2uCzcPjgg....'
}
res = requests.get('https://www.instagram.com/minchen333/?hl=zh-tw',headers = headers)

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(res.text,'lxml')

# %%
import re
re.search('window._sharedData', res.text)
# Out:
# <re.Match object; span=(18962, 18980), match='window._sharedData'>

# %%
import re, json
m = re.search('window._sharedData =(.*);', res.text)
m.group(1)
# Out:
# ' {"config":{"csrf_token":"ANFV9V6YPFUaUcdXiuQshMHpakJ5BX7c","viewer":{"biography":"\\u201cExploring the unknown requires tolerating uncertainty.\\u201d","category_name":null,"external_url":null,"fbid":"17841401839772437","full_name":"Yi-Chien Kevin Lee","has_phone_number":true,"has_profile_pic":true,"has_tabbed_inbox":false,"id":"1436029325","is_joined_recently":false,"is_private":false,"is_professional_account":false,"profile_pic_url":"https://instagram.ftpe7-1.fna.fbcdn.net/v/t51.2885-19/s150x150/97884857_628563968003627_1588720437288763392_n.jpg?tp=1\\u0026_nc_ht=instagram.ftpe7-1.fna.fbcdn.net\\u0026_nc_ohc=cfeMNX55BD4AX-qZpyX\\u0026edm=ABfd0MgAAAAA\\u0026ccb=7-4\\u0026oh=1552f70dd8dc4a1a81f9eb298ff7cb6d\\u0026oe=60ABBD94\\u0026_nc_sid=7bff83","profile_pic_url_hd":"https://instagram.ftpe7-1.fna.fbcdn.net/v/t51.2885-19/s320x320/97884857_628563968003627_1588720437288763392_n.jpg?tp=1\\u0026_nc_ht=instagram.ftpe7-1.fna.fbcdn.net\\u0026_nc_ohc=cfeMNX55BD4AX-qZpyX\\u0026edm=ABfd0MgAA
# ...

# %%
import re, json
m = re.search('window._sharedData =(.*);', res.text)
jd = json.loads(m.group(1))
jd
# Out:
# {'config': {'csrf_token': 'ANFV9V6YPFUaUcdXiuQshMHpakJ5BX7c',
#   'viewer': {'biography': '“Exploring the unknown requires tolerating uncertainty.”',
#    'category_name': None,
#    'external_url': None,
#    'fbid': '17841401839772437',
#    'full_name': 'Yi-Chien Kevin Lee',
#    'has_phone_number': True,
#    'has_profile_pic': True,
#    'has_tabbed_inbox': False,
#    'id': '1436029325',
#    'is_joined_recently': False,
#    'is_private': False,
#    'is_professional_account': False,
#    'profile_pic_url': 'https://instagram.ftpe7-1.fna.fbcdn.net/v/t51.2885-19/s150x150/97884857_628563968003627_1588720437288763392_n.jpg?tp=1&_nc_ht=instagram.ftpe7-1.fna.fbcdn.net&_nc_ohc=cfeMNX55BD4AX-qZpyX&edm=ABfd0MgAAAAA&ccb=7-4&oh=1552f70dd8dc4a1a81f9eb298ff7cb6d&oe=60ABBD94&_nc_sid=7bff83',
# ...

# %%
import json

with open ('1.json','w') as f:
    f.write(json.dumps(jd))

# %%
for edge in jd['entry_data']['ProfilePage'][0]['graphql']['user']['edge_owner_to_timeline_media']['edges']:
    print(edge.get('node').get('display_url'))
    break
# Out:
# https://instagram.ftpe7-4.fna.fbcdn.net/v/t51.2885-15/e35/s1080x1080/175927570_276567540811147_5150827138559773091_n.jpg?tp=1&_nc_ht=instagram.ftpe7-4.fna.fbcdn.net&_nc_cat=107&_nc_ohc=zt80kV6cNEkAX_EkVZF&edm=ABfd0MgAAAAA&ccb=7-4&oh=20520fba053f27da02825e6d04f3d36a&oe=60AA34FB&_nc_sid=7bff83

# %%
url = 'https://instagram.ftpe7-4.fna.fbcdn.net/v/t51.2885-15/e35/s1080x1080/175927570_276567540811147_5150827138559773091_n.jpg?tp=1&_nc_ht=instagram.ftpe7-4.fna.fbcdn.net&_nc_cat=107&_nc_ohc=zt80kV6cNEkAX_EkVZF&edm=ABfd0MgAAAAA&ccb=7-4&oh=20520fba053f27da02825e6d04f3d36a&oe=60AA34FB&_nc_sid=7bff83'
url
# Out:
# 'https://instagram.ftpe7-4.fna.fbcdn.net/v/t51.2885-15/e35/s1080x1080/175927570_276567540811147_5150827138559773091_n.jpg?tp=1&_nc_ht=instagram.ftpe7-4.fna.fbcdn.net&_nc_cat=107&_nc_ohc=zt80kV6cNEkAX_EkVZF&edm=ABfd0MgAAAAA&ccb=7-4&oh=20520fba053f27da02825e6d04f3d36a&oe=60AA34FB&_nc_sid=7bff83'

# %%
url.split('?')[0].split('/')[-1]
# Out:
# '175927570_276567540811147_5150827138559773091_n.jpg'

# %%
url = 'https://instagram.ftpe7-4.fna.fbcdn.net/v/t51.2885-15/e35/s1080x1080/175927570_276567540811147_5150827138559773091_n.jpg?tp=1&_nc_ht=instagram.ftpe7-4.fna.fbcdn.net&_nc_cat=107&_nc_ohc=zt80kV6cNEkAX_EkVZF&edm=ABfd0MgAAAAA&ccb=7-4&oh=20520fba053f27da02825e6d04f3d36a&oe=60AA34FB&_nc_sid=7bff83'

# %%
def getIdol(url):
    fname = url.split('?')[0].split('/')[-1]
    res = requests.get(url)
    with open (fname, 'wb') as f:
        f.write(res.content)

# %%
for edge in jd['entry_data']['ProfilePage'][0]['graphql']['user']['edge_owner_to_timeline_media']['edges']:
    getIdol(edge.get('node').get('display_url'))

# %%
### flow of IG

# %%
import requests
headers = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.85 Safari/537.36',
    'cookie': 'mid=XwV5YAALAAE90Aw6LG7W7laZDp5m; ig_did=91D806D8-1651-43C7-BAA2-73678E1445F6; fbm_124024574287414=base_domain=.instagram.com; shbid=3317; shbts=1619426000.8690197; rur=RVA; ig_nrcb=1; csrftoken=ANFV9V6YPFUaUcdXiuQshMHpakJ5BX7c; ds_user_id=1436029325; sessionid=1436029325%3AI6G5IavOGE8yqW%3A18; fbsr_124024574287414=Rmw_BgAqOV2z_HvA9RbnGYF0TQt3hTnJHq2uCzcPjgg....; fbsr_124024574287414=Rmw_BgAqOV2z_HvA9RbnGYF0TQt3hTnJHq2uCzcPjgg....'
}
res = requests.get('https://www.instagram.com/henrylin0823/',headers = headers)

# %%
import re, json
m = re.search('window._sharedData =(.*);', res.text)
jd = json.loads(m.group(1))
jd
# Out:
# {'config': {'csrf_token': 'ANFV9V6YPFUaUcdXiuQshMHpakJ5BX7c',
#   'viewer': {'biography': '“Exploring the unknown requires tolerating uncertainty.”',
#    'category_name': None,
#    'external_url': None,
#    'fbid': '17841401839772437',
#    'full_name': 'Yi-Chien Kevin Lee',
#    'has_phone_number': True,
#    'has_profile_pic': True,
#    'has_tabbed_inbox': False,
#    'id': '1436029325',
#    'is_joined_recently': False,
#    'is_private': False,
#    'is_professional_account': False,
#    'profile_pic_url': 'https://instagram.ftpe7-1.fna.fbcdn.net/v/t51.2885-19/s150x150/97884857_628563968003627_1588720437288763392_n.jpg?tp=1&_nc_ht=instagram.ftpe7-1.fna.fbcdn.net&_nc_ohc=cfeMNX55BD4AX-qZpyX&edm=ABfd0MgAAAAA&ccb=7-4&oh=1552f70dd8dc4a1a81f9eb298ff7cb6d&oe=60ABBD94&_nc_sid=7bff83',
# ...

# %%
import json

with open ('1.json','w') as f:
    f.write(json.dumps(jd))

# %%
for edge in jd['entry_data']['ProfilePage'][0]['graphql']['user']['edge_owner_to_timeline_media']['edges']:
    print(edge.get('node').get('display_url'))
    break
# Out:
# https://instagram.ftpe7-1.fna.fbcdn.net/v/t51.2885-15/e35/s1080x1080/151700014_690454538299582_2876795133011155417_n.jpg?tp=1&_nc_ht=instagram.ftpe7-1.fna.fbcdn.net&_nc_cat=110&_nc_ohc=qe5cePnPbAAAX9c49VK&edm=ABfd0MgAAAAA&ccb=7-4&oh=fcba1620a4932f6903a52d0a7f5b840f&oe=60AC56B2&_nc_sid=7bff83

# %%
def getIdol(url):
    fname = url.split('?')[0].split('/')[-1]
    res = requests.get(url)
    with open (fname, 'wb') as f:
        f.write(res.content)

# %%
for edge in jd['entry_data']['ProfilePage'][0]['graphql']['user']['edge_owner_to_timeline_media']['edges']:
    getIdol(edge.get('node').get('display_url'))
